# %%
import pickle
from pathlib import Path
import pandas as pd

# %%
file_path = Path("output/GROUPE_LANDOR/LANDOR_tables.pkl")

with open(file_path, "rb") as f:
    data = pickle.load(f)

print("Type de données :", type(data))
# Out:
# Type de données : <class 'dict'>

# %%
print("Contenu (clés principales) :")
print(data.keys())
# Out:
# Contenu (clés principales) :
# dict_keys([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %%
year = 2014  # 👉 change ici l'année que tu veux

if year in data:
    tables = data[year]

    print("="*60)
    print(f"📅 Année : {year}")
    print(f"📊 Nombre de tableaux : {len(tables)}")

    for i, df in enumerate(tables):
        print("\n------------------------------")
        print(f"Tableau {i+1}")
        display(df)
else:
    print("❌ Année introuvable :", year)
# Out:
# ============================================================
# 📅 Année : 2014
# 📊 Nombre de tableaux : 31
#
# ------------------------------
# Tableau 1
#                                          ACTIFS Unnamed: 0    Unnamed: 1  \
# 0                                           NaN      Notes  31-déc.-2014
# 1                           ACTIFS NON COURANTS        NaN           NaN
# 2                                           NaN        NaN           NaN
# 3                            Actifs Immobilisés        NaN           NaN
# 4                 IMMOBILISATIONS INCORPORELLES        4.1     2 473 814
# 5                          Moins(Amortissement)        NaN   <1 139 760>
# 6           Total Immobilisations incorporelles        NaN     1 334 054
# 7                                           NaN        NaN           NaN
# 8                   IMMOBILISATIONS CORPORELLES        4.2    39 663 411
# 9                          Moins(Amortissement)        NaN  <13 900 515>
# 10        Total Immobilisations corporelles (*)        NaN    25 762 896
# 11                                          NaN        NaN           NaN
# 12                                          NaN        NaN           NaN
# 13                  IMMOBILISATIONS FINANCIERES        4.3        25 338
# 14                                          NaN        NaN           NaN
# 15                 Total des Actifs Immobilisés        NaN    27 122 288
# 16                                          NaN        NaN           NaN
# 17                   Autres Actifs Non Courants        4.4     2 169 429
# 18                                          NaN        NaN           NaN
# 19                TOTAL DES ACTIFS NON COURANTS        NaN    29 291 717
# 20                                          NaN        NaN           NaN
# 21                              ACTIFS COURANTS        NaN           NaN
# 22                                          NaN        NaN           NaN
# 23                                       Stocks        4.5    12 813 063
# 24                         Moins  ( provisions)        NaN     <208 841>
# 25                             Total des Stocks        NaN    12 604 222
# 26                                          NaN        NaN           NaN
# 27                                          NaN        NaN           NaN
# 28                 Clients Et Comptes Rattachés        4.6     9 038 028
# 29                         Moins  ( provisions)        NaN   <2 100 280>
# 30   Total des Clients et comptes rattachés (*)        NaN     6 937 748
# 31                                          NaN        NaN           NaN
# 32                       Autres Actifs Courants        4.7     5 084 820
# 33                                          NaN        NaN           NaN
# 34  Liquidités Et Equivalents De Liquidités (*)        4.8     1 886 007
# 35                                          NaN        NaN           NaN
# 36                    TOTAL DES ACTIFS COURANTS        NaN    26 512 797
# 37                                          NaN        NaN           NaN
# 38                             TOTAL DES ACTIFS        NaN    55 804 514
#
#       Unnamed: 2
# 0   31-déc.-2013
# 1            NaN
# 2            NaN
# 3            NaN
# 4      1 630 914
# 5      <900 535>
# 6        730 379
# 7            NaN
# 8     35 887 390
# 9   <10 994 265>
# 10    24 893 126
# 11           NaN
# 12           NaN
# 13        36 009
# 14           NaN
# 15    25 659 513
# 16           NaN
# 17     2 460 877
# 18           NaN
# 19    28 120 390
# 20           NaN
# 21           NaN
# 22           NaN
# 23    17 476 884
# 24   <2 212 131>
# 25    15 264 753
# 26           NaN
# 27           NaN
# 28     7 403 325
# 29   <1 657 454>
# 30     5 745 871
# 31           NaN
# 32     7 656 192
# 33           NaN
# 34     3 470 474
# 35           NaN
# 36    32 137 290
# 37           NaN
# 38    60 257 680
# ------------------------------
# Tableau 2
#                           CAPITAUX PROPRES ET PASSIFS Unnamed: 0  \
# 0                                                 NaN      Notes
# 1                                    CAPITAUX PROPRES        NaN
# 2                                                 NaN        NaN
# 3                                      Capital Social        5.1
# 4                                                 NaN        NaN
# 5                                Réserves consolidées        5.1
# 6                                                 NaN        NaN
# 7                             Autres Capitaux Propres        5.1
# 8                                                 NaN        NaN
# 9                                 Résultat Consolidés        5.1
# 10                                                NaN        NaN
# 11                              Intérêts minoritaires        NaN
# 12                                                NaN        NaN
# 13       TOTAL DES CAPITAUX PROPRES APRES AFFECTATION        NaN
# 14                                                NaN        NaN
# 15                                            PASSIFS        NaN
# 16                                                NaN        NaN
# 17                               Passifs Non Courants        NaN
# 18                                                NaN        NaN
# 19                                           Emprunts        5.2
# 20                                         Provisions        5.3
# 21                     Total Des Passifs Non Courants        NaN
# 22                                                NaN        NaN
# 23                                   Passifs Courants        NaN
# 24                                                NaN        NaN
# 25              Fournisseurs Et Comptes Rattachés (*)        5.4
# 26                                                NaN        NaN
# 27                        Autres Passifs Courants (*)        5.5
# 28                                                NaN        NaN
# 29  Concours Bancaires Et Autres Passifs Financier...        5.6
# 30                                                NaN        NaN
# 31                         Total Des Passifs Courants        NaN
# 32                                                NaN        NaN
# 33                                  TOTAL DES PASSIFS        NaN
# 34                                                NaN        NaN
# 35              TOTAL DES CAPITAUX PROPRES ET PASSIFS        NaN
#
#       Unnamed: 1    Unnamed: 2
# 0   31-déc.-2014  31-déc.-2013
# 1            NaN           NaN
# 2            NaN           NaN
# 3      4 846 875     4 700 000
# 4            NaN           NaN
# 5   <11 026 566>   <4 498 074>
# 6            NaN           NaN
# 7     12 043 724    11 686 522
# 8            NaN           NaN
# 9    <2 825 591>   <6 081 569>
# 10           NaN           NaN
# 11           139       153 375
# 12           NaN           NaN
# 13     3 038 581     5 960 254
# 14           NaN           NaN
# 15           NaN           NaN
# 16           NaN           NaN
# 17           NaN           NaN
# 18           NaN           NaN
# 19    12 979 557    13 436 843
# 20       641 470       214 470
# 21    13 621 027    13 651 313
# 22           NaN           NaN
# 23           NaN           NaN
# 24           NaN           NaN
# 25     8 443 362    15 640 324
# 26           NaN           NaN
# 27     3 580 940     3 962 025
# 28           NaN           NaN
# 29    27 120 604    21 043 763
# 30           NaN           NaN
# 31    39 144 906    40 646 112
# 32           NaN           NaN
# 33    52 765 933    54 297 425
# 34           NaN           NaN
# 35    55 804 514    60 257 680
# ------------------------------
# Tableau 3
#                                  ETAT DE RESULTAT Unnamed: 0    Unnamed: 1  \
# 0                                             NaN      Notes  31-déc.-2014
# 1                                             NaN        NaN           NaN
# 2                         PRODUITS D'EXPLOITATION        6.1           NaN
# 3                                         Revenus        NaN    67 000 511
# 4                                             NaN        NaN           NaN
# 5                  Autres Produits d'Exploitation        NaN       184 722
# 6                                             NaN        NaN           NaN
# 7               Total Des Produits D'exploitation        NaN    67 185 233
# 8                                             NaN        NaN           NaN
# 9                          CHARGES D'EXPLOITATION        NaN           NaN
# 10     Variation de Stocks des Produits Finis (*)        NaN     <162 565>
# 11                                            NaN        NaN           NaN
# 12                               Achats Consommés        6.2    42 129 153
# 13                                         Achats        NaN    39 565 859
# 14                      Variations Des Stocks (*)        NaN     2 563 294
# 15                                            NaN        NaN           NaN
# 16                                  Autres achats        6.3     2 929 471
# 17                           Charges De Personnel        6.4     8 973 033
# 18     Dotations Aux Amortissements Et Provisions        6.5     5 185 286
# 19              Autres Charges D'exploitation (*)        6.6     8 958 890
# 20               Total Des Charges D'exploitation        NaN    68 175 833
# 21                                            NaN        NaN           NaN
# 22                        RESULTAT D'EXPLOITATION        NaN     <828 035>
# 23                                            NaN        NaN           NaN
# 24                 Charges Financières Nettes (*)        6.7     2 666 689
# 25                        Produits des palcements        NaN             -
# 26                        Autres Gains Ordinaires        6.8       445 742
# 27                       Autres Pertes Ordinaires        6.9        56 128
# 28                                            NaN        NaN           NaN
# 29  RESULTAT DES ACTIVITES ORDINAIRES AVANT IMPOT        NaN   <3 105 110>
# 30                                            NaN        NaN           NaN
# 31                        Impot sur les bénéfices        NaN     <155 881>
# 32                                  Impôt différé       6.10       272 350
# 33  RESULTAT DES ACTIVITES ORDINAIRES APRES IMPOT        NaN   <2 988 641>
#
#       Unnamed: 2
# 0   31-déc.-2013
# 1            NaN
# 2            NaN
# 3     70 263 927
# 4            NaN
# 5        867 299
# 6            NaN
# 7     71 131 227
# 8            NaN
# 9            NaN
# 10     <578 015>
# 11           NaN
# 12    47 398 746
# 13    48 970 943
# 14   <1 572 197>
# 15           NaN
# 16     3 670 330
# 17     7 805 895
# 18     6 503 832
# 19     9 527 630
# 20    74 906 433
# 21           NaN
# 22   <3 197 192>
# 23           NaN
# 24     3 154 363
# 25        13 203
# 26       411 811
# 27         5 227
# 28           NaN
# 29   <5 931 767>
# 30           NaN
# 31     <403 158>
# 32       253 357
# 33   <6 081 569>
# ------------------------------
# Tableau 4
#                            ETAT DE FLUX DE TRESORERIE    Unnamed: 0
# 0                                        31-déc.-2014  31-déc.-2013
# 1                                                 NaN           NaN
# 2            FLUX DE TRESORERIE LIES A L'EXPLOITATION           NaN
# 3                                                 NaN           NaN
# 4          Encaissements Reçus des Clients 76 161 867    76 475 780
# 5                        Autres Encaissements 746 849     4 147 355
# 6        Sommes Versées aux Fournisseurs <59 177 539>  <70 098 701>
# 7                       Autres Paiements <19 468 631>  <16 023 934>
# 8                            Intérêts payés <914 295>     <602 675>
# 9                                                 NaN           NaN
# 10  Flux de Trésorerie provenant de (affecté à) l'...   <6 102 175>
# 11                                                NaN           NaN
# 12         FLUX DE TRESORERIE LIES A L'INVESTISSEMENT           NaN
# 13                                                NaN           NaN
# 14  Décaissements / acquisitions d'immob corp et i...  <10 683 924>
# 15  Encaissements / cessions d'immob corp et incor...       105 884
# 16   Décaissements / acquisitions d'immob financières           NaN
# 17                                                NaN       <7 720>
# 18  Flux de Trésorerie provenant des (affecté aux)...           NaN
# 19          <10 585 760> d'investissement <2 547 876>           NaN
# 20                                                NaN           NaN
# 21             FLUX DE TRESORERIE LIES AU FINANCEMENT           NaN
# 22                                                NaN           NaN
# 23       Encaissements suite à l'émission d'actions -    10 920 000
# 24             Encaissements provenant des emprunts -     8 500 000
# 25   Encaissements sur Financement de Stock et autres           NaN
# 26                 Encaissements subvention 1 250 649     1 905 000
# 27     Décaissements sur Financement de Stock 788 628           NaN
# 28               Remboursement d'emprunts <1 212 142>   <3 694 479>
# 29                                                NaN           NaN
# 30  Flux de Trésorerie provenant des (affecté aux)...           NaN
# 31                  17 630 521 de financement 827 135           NaN
# 32                                                NaN           NaN
# 33   INCIDENCES DES VARIATIONS DES TAUX DE CHANGE SUR           NaN
# 34                                                NaN           NaN
# 35  LES LIQUIDITES ET EQUIVALENTS DE LIQUIDITES 21...     <821 229>
# 36                                                NaN           NaN
# 37                VARIATION DE TRESORERIE <4 157 987>       121 357
# 38                                                NaN           NaN
# 39      Trésorerie au début de l'exercice <9 512 110>   <9 633 468>
# 40                                                NaN           NaN
# 41  Trésorerie à la clôture de l'exercice <13 670 ...   <9 512 110>
# ------------------------------
# Tableau 5
#                    Unnamed: 0 Désignation  Qualité Pourcentage de  \
# 0                         NaN         NaN      NaN       contrôle
# 1                   1_LAND’OR         NaN     Mère          100 %
# 2                       2_LFS         NaN  Filiale        99,97 %
# 3       3_ ECHARIKA ALYBIA...         NaN  Filiale           65 %
# 4                      4_LMFS         NaN  Filiale           100%
# 5  5_LAND’OR USA HOLDINGS INC         NaN  Filiale           100%
#
#              Méthode de
# 0         consolidation
# 1  Société consolidante
# 2   Intégration globale
# 3   Intégration globale
# 4   Intégration globale
# 5   Intégration globale
# ------------------------------
# Tableau 6
#   2.12Ecart de conversion\r\rLa comptabilisation des opérations réalisées entre deux sociétés utilisant des devises différentes conduit\rà la clôture à des écarts lors de la conversion des comptes des entreprises étrangères. Le résultat et la\rsituationfinancièred’uneentitédoiventêtreconvertisdelamonnaiefonctionnelleàuneautre\rmonnaie de présentation.\r-Les actifs et les passifs de chaque bilan présenté doivent être convertis au cours de clôture à la\rdate de chacun de ces bilans ;\r-Les produits et les charges de chaque compte de résultat doivent être convertis au cours de\rchange en vigueur aux dates des transactions ;et\r-Tous les écarts de change en résultant doivent être comptabilisés en tant que composante\rdistincte des capitaux propres.\r\r2.13Impôt différé\r\rLes sociétés du Land’Or sont soumises à l’impôt sur les sociétés (IS) selon les règles et les\rtaux en vigueur du pays ou la société est implantée.\rIl a été tenu compte d’un impôt différé pour les retraitements de consolidation ayant une incidence sur\rle résultat ainsi qu’une mise à jour des actifs et des passifs des impôts différés au taux en vigueur à la\rclôture de l’exercice comptable.\r\r3CHANGEMENT DE METHODE DE PRESENTATION\r\rAu cours de l’exercice 2014, la  société Land’Or a procédé à un changement dans la présentation de\rcertains postes des états financiers. La colonne comparative a été retraitée. Les principaux\rretraitements se présentent comme suit :\r\r3.1Changement de méthode de présentation des postes de bilan:\r\r•Les immobilisations à statut juridique particuliers ont été reclassées vers la catégorie immobilisations\rcorporelles.\r\r•Les avances clients précédemment classées parmi la rubrique « clients et comptes  rattachés »\rsont désormais présentées parmi les autres passifs courants.\r\r•Les chèques à encaisser précédemment classés parmi la rubrique « Liquidités et équivalents de\rLiquidités » sont désormais présentés parmi les clients et comptes rattachés.\r\r•Les échéances à moins d’un an relatives au contrat de leasing présentées parmi les « fournisseurs\ret comptes rattachés » lors des périodes précédentes ont été reclassées parmi les « Concours\rbancaires et autres passifs financiers ».\r\rRetraitement des  postes du bilan au 31 décembre 2013:\r\r\r31/12/2013 avant31/12/2013 après\rPostes retraitésreclassement reclassement\rreclassement\rImmobilisations à statut juridique particulier1 048 776<1 048 776>-\rImmobilisations corporelles23 844 3491 048 77624 893 125\rClients et comptes rattachés6 708 602694 7237 403 325\rAutres Passifs Courants<4 353 898>391 874<3 962 025>\rLiquidités et équivalents de liquidités4 165 197<694 723>3 470 474\rFournisseurs et compte rattachés<15 613 477><26 847><15 640 324>\rAutres actifs courants7 821 92838 4237 860 351\rConcours bancaires et autres passifs financiers<20 640 314><403 450><21 043 763>\r\r\r\r3.2Changement de méthode de présentation des postes de l’état de résultat\r\r•La variation de stocks de produits semi finis précédemment présentée parmi la variation de stock\rde matières premières a été reclassée vers la variation de stock de produits finis.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                                        Unnamed: 0 Unnamed: 1  \
# 0                                             NaN        NaN
# 1                                             NaN        NaN
# 2  Immobilisations à statut juridique particulier        NaN
# 3                     Immobilisations corporelles        NaN
#
#          Unnamed: 2    Unnamed: 3 Unnamed: 4        Unnamed: 5 Unnamed: 6
# 0  31/12/2013 avant           NaN        NaN  31/12/2013 après        NaN
# 1      reclassement  reclassement        NaN               NaN        NaN
# 2               NaN           NaN        NaN               NaN        NaN
# 3               NaN           NaN        NaN               NaN        NaN
# ------------------------------
# Tableau 7
#   2.12Ecart de conversion\r\rLa comptabilisation des opérations réalisées entre deux sociétés utilisant des devises différentes conduit\rà la clôture à des écarts lors de la conversion des comptes des entreprises étrangères. Le résultat et la\rsituationfinancièred’uneentitédoiventêtreconvertisdelamonnaiefonctionnelleàuneautre\rmonnaie de présentation.\r-Les actifs et les passifs de chaque bilan présenté doivent être convertis au cours de clôture à la\rdate de chacun de ces bilans ;\r-Les produits et les charges de chaque compte de résultat doivent être convertis au cours de\rchange en vigueur aux dates des transactions ;et\r-Tous les écarts de change en résultant doivent être comptabilisés en tant que composante\rdistincte des capitaux propres.\r\r2.13Impôt différé\r\rLes sociétés du Land’Or sont soumises à l’impôt sur les sociétés (IS) selon les règles et les\rtaux en vigueur du pays ou la société est implantée.\rIl a été tenu compte d’un impôt différé pour les retraitements de consolidation ayant une incidence sur\rle résultat ainsi qu’une mise à jour des actifs et des passifs des impôts différés au taux en vigueur à la\rclôture de l’exercice comptable.\r\r3CHANGEMENT DE METHODE DE PRESENTATION\r\rAu cours de l’exercice 2014, la  société Land’Or a procédé à un changement dans la présentation de\rcertains postes des états financiers. La colonne comparative a été retraitée. Les principaux\rretraitements se présentent comme suit :\r\r3.1Changement de méthode de présentation des postes de bilan:\r\r•Les immobilisations à statut juridique particuliers ont été reclassées vers la catégorie immobilisations\rcorporelles.\r\r•Les avances clients précédemment classées parmi la rubrique « clients et comptes  rattachés »\rsont désormais présentées parmi les autres passifs courants.\r\r•Les chèques à encaisser précédemment classés parmi la rubrique « Liquidités et équivalents de\rLiquidités » sont désormais présentés parmi les clients et comptes rattachés.\r\r•Les échéances à moins d’un an relatives au contrat de leasing présentées parmi les « fournisseurs\ret comptes rattachés » lors des périodes précédentes ont été reclassées parmi les « Concours\rbancaires et autres passifs financiers ».\r\rRetraitement des  postes du bilan au 31 décembre 2013:\r\r\r31/12/2013 avant31/12/2013 après\rPostes retraitésreclassement reclassement\rreclassement\rImmobilisations à statut juridique particulier1 048 776<1 048 776>-\rImmobilisations corporelles23 844 3491 048 77624 893 125\rClients et comptes rattachés6 708 602694 7237 403 325\rAutres Passifs Courants<4 353 898>391 874<3 962 025>\rLiquidités et équivalents de liquidités4 165 197<694 723>3 470 474\rFournisseurs et compte rattachés<15 613 477><26 847><15 640 324>\rAutres actifs courants7 821 92838 4237 860 351\rConcours bancaires et autres passifs financiers<20 640 314><403 450><21 043 763>\r\r\r\r3.2Changement de méthode de présentation des postes de l’état de résultat\r\r•La variation de stocks de produits semi finis précédemment présentée parmi la variation de stock\rde matières premières a été reclassée vers la variation de stock de produits finis.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                                        Unnamed: 0 Unnamed: 1  \
# 0                                             NaN        NaN
# 1                                             NaN        NaN
# 2  Immobilisations à statut juridique particulier        NaN
# 3                     Immobilisations corporelles        NaN
#
#          Unnamed: 2 Unnamed: 3
# 0  31/12/2013 avant        NaN
# 1      reclassement        NaN
# 2               NaN        NaN
# 3               NaN        NaN
# ------------------------------
# Tableau 8
# ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1                     Intérêts sur crédits bancaires        NaN        NaN
# 2                 Autres charges d’intérêts intérêts        NaN        NaN
# 3                               Différence de change        NaN        NaN
# 4  Autres frais et commissions sur prestations de...        NaN        NaN
# 5                                              Total        NaN        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7
# 0  31/12/2014        NaN        NaN  31/12/2013        NaN
# 1     919 751        NaN        NaN     656 773        NaN
# 2     130 594        NaN        NaN      68 351        NaN
# 3   <277 115>        NaN        NaN     698 369        NaN
# 4   1 893 459        NaN        NaN   1 730 870        NaN
# 5   2 666 689        NaN        NaN   3 154 363        NaN
# ------------------------------
# Tableau 31
#   6.6Autres charges d'exploitation\r\rLe solde de ce compte se détaille comme suit :\r\r31/12/201431/12/2013\rAutres Services extérieurs6 158 3817 219 575\rServices extérieurs ACE2 257 2771 778 482\rCharges diverses ordinaires132 657108 866\rImpôts et taxes410 405420 707\rTotal8 958 7209 527 630\r\r\r\r\r6.7Charges financières\r\rLe solde de cette rubrique se détaille comme suit :\r\r31/12/201431/12/2013\rIntérêts sur crédits bancaires919 751656 773\rAutres charges d’intérêts intérêts130 59468 351\rDifférence de change<277 115>698 369\rAutres frais et commissions sur prestations de services1 893 4591 730 870\rTotal2 666 6893 154 363\r\r\r6.8Autres gains ordinaires\r\rLe solde de cette rubrique se détaille comme suit :\r\r31/12/201431/12/2013\rProduits Divers Ordinaires136 27173 782\rProduits sur cession d’immobilisations276 32894 332\rReprise sur provision243 697\rTransfert de charges33 143\r\rTotal445 742411 811\r\r6.9Autres Pertes  ordinaires :\r\rLe solde de cette rubrique se détaille comme suit :\r\r31/12/201431/12/2013\rPénalités24 3095 227\rPertes sur créances  irrécouvrables31 819-\rTotal56 1285 227\r\r6.10Impôts sur les sociétés\r\rLe solde de cette rubrique se détaille comme suit :\r\r\r31/12/201431/12/2013\rImpôt sur les sociétés155 881403 158\rImpôt différé<272 350><253 357>\rTotal<116 469>149 801  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                             Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                                  NaN        NaN        NaN  31/12/2014
# 1                            Pénalités        NaN        NaN      24 309
# 2  Pertes sur créances  irrécouvrables        NaN        NaN      31 819
# 3                                Total        NaN        NaN      56 128
#
#   Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7
# 0        NaN        NaN  31/12/2013        NaN
# 1        NaN        NaN       5 227        NaN
# 2        NaN        NaN           -        NaN
# 3        NaN        NaN       5 227        NaN
